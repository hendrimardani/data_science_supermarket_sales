# %%
About Dataset

Context

The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.

Attribute information

Invoice id: Computer generated sales slip invoice identification number

Branch: Branch of supercenter (3 branches are available identified by A, B and C).

City: Location of supercenters

Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.

Gender: Gender type of customer

Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel

Unit price: Price of each product in $

Quantity: Number of products purchased by customer

Tax: 5% tax fee for customer buying

Total: Total price including tax

Date: Date of purchase (Record available from January 2019 to March 2019)

Time: Purchase time (10am to 9pm)

Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)

COGS: Cost of goods sold

Gross margin percentage: Gross margin percentage

Gross income: Gross income

Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

link dataset: https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales
# Out:
#   Cell In[4], line 31
#     Time: Purchase time (10am to 9pm)
#                           ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
print(f"Pandas version = {pd.__version__}")
print(f"Matplotlib version = {matplotlib.__version__}")
print(f"Seaborn version = {sns.__version__}")
# Out:
# Pandas version = 2.2.2
# Matplotlib version = 3.7.5
# Seaborn version = 0.12.2

# %% [markdown]
# ### Exploratory Data Analisys (EDA)

# %%
data = pd.read_csv("/kaggle/input/supermarket-sales123/supermarket_sales - Sheet1.csv")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
plot = data["Branch"].value_counts()
ax = plot.plot.barh()
ax.set_title("Daftar Cabang Supermarket")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data["City"].value_counts()
ax = plot.plot.barh()
ax.set_title("Daftar Kota Supermarket")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data["Customer type"].value_counts()
ax = plot.plot.barh()
ax.set_title("Daftar Jenis Tipe Pelanggan")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data["Product line"].value_counts()
ax = plot.plot.barh()
ax.set_title("Daftar Kategori Makanan dan Minuman")

for container in ax.containers:
    ax.bar_label(container)

# %%
# Change type data feature Date and Time to datetime
data["Date"] = data["Date"].astype("datetime64[ns]")
data["Time"] = data["Time"].astype("datetime64[ns]")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
fig, ax = plt.subplots()
sns.kdeplot(data=data, x="Date", y="gross income", fill=True, cbar=True);
plt.xticks(rotation=45);  # Ubah nilai rotasi untuk mengatur kemiringan
ax.set_title("Pendapatan Kotor Paling Banyak Tiap Tahun")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots()
sns.kdeplot(data=data, x="Time", y="Total", fill=True, cbar=True)
plt.xticks(rotation=45);  # Ubah nilai rotasi untuk mengatur kemiringan
ax.set_title("Total Harga Termasuk Pajak yang Paling Banyak Tiap Jam")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, ax = plt.subplots()
plot = data["Payment"].value_counts()
ax = plot.plot.barh()
ax.set_title("Pembayaran yang Paling Banyak Digunakan")
ax.legend()

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Gender", "Customer type"])["Rating"].mean().unstack()
ax = plot.plot.barh()
ax.set_title("Kartu Pelanggan yang Paling Banyak Digunakan Berdasarkan Jenis Kelamin")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch", "Customer type"])["gross income"].mean().unstack()
ax = plot.plot.barh()
ax.set_title("Pendapatan Kotor Berdasarkan Kartu Pelanggan dan Cabang Supermarket")
ax.legend(loc="lower left")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch", "Customer type"])["gross margin percentage"].mean().unstack()
ax = plot.plot.barh()
ax.set_title("Pendapatan Kotor Berdasarkan Kartu Pelanggan dan Cabang Supermarket")
ax.legend(loc="lower left")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch", "Customer type"])["cogs"].mean().unstack()
ax = plot.plot.barh()
ax.set_title("Biaya Barang yang Terjual Berdasarkan Kartu Pelanggan dan Cabang Supermarket")
ax.legend(loc="lower left")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch", "Customer type"])["Total"].mean().unstack()
ax = plot.plot.barh()
ax.set_title("Total Harga Termasuk Pajak Berdasarkan Kartu Pelanggan dan Cabang Supermarket")
ax.legend(loc="lower left")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch"])["Rating"].mean()
ax = plot.plot.barh()
ax.set_title("Total Rating Tertinggi Berdasarkan Cabang Supermarket")
ax.legend(loc="center")

for container in ax.containers:
    ax.bar_label(container)

# %%
plot = data.groupby(["Branch"])["Tax 5%"].mean()
ax = plot.plot.barh()
ax.set_title("Rata-rata Pajak Berdasarkan Cabang Supermarket")
ax.legend()
for container in ax.containers:
    ax.bar_label(container)

# %%
sns.scatterplot(data=data, x="Tax 5%", y="Total").set(title="Total Harga Termasuk Pajak")
plt.show()

# %%
sns.scatterplot(data=data, x="Tax 5%", y="Unit price").set(title="Harga Barang per Unit dengan Pajak")
plt.show()

# %%
sns.scatterplot(data=data, x="Total", y="Quantity").set(title="Harga Barang per Unit dengan Pajak")
plt.show()

# %%
plot = data.groupby(["Product line"])["Quantity"].mean()
ax = plot.plot.barh()
ax.set_title("Jumlah Produk yang Paling Banyak Dibeli")
ax.legend()
plt.show()

# %%
plot = data.groupby(["Product line", "Gender"])["Quantity"].mean()
ax = plot.plot.barh()
ax.set_title("Jumlah Produk yang Paling Banyak Dibeli Berdasarkan Jenis Kelamin")
ax.legend()
plt.show()

# %%
sns.scatterplot(data=data, x="cogs", y="Tax 5%").set(title="Biaya Barang yang Terjual dengan Pajak")
plt.show()

# %%
sns.jointplot(data=data, x="Unit price", y="Total")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data.corr(numeric_only=True)
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...
